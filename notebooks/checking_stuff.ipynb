# %%
cd /app
# Out:
# /app
# /home/andrew/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
ls
# Out:
# LICENSE   README.md  data/    docker-compose.yaml  notebooks/   pyproject.toml
# Makefile  cybulde/   docker/  logs.log             poetry.lock  setup.cfg

# %%
from cybulde.data_processing.dataset_cleaners import SpellCorrectionDatasetCleaner
from cybulde.utils.utils import SpellCorrectionModel

# %%
spell_checking_model = SpellCorrectionModel()
cleaner = SpellCorrectionDatasetCleaner(spell_checking_model)

# %%
text = "couqdn'tread in sixtgrade and ins pired him"

# %%
cleaner(text)
# Out:
# "couldn't read in six grade and inspired him"
